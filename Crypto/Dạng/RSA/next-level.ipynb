# %%
from Crypto.Util import number
from Crypto.Util.number import *
from sympy import integer_nthroot
def nextprime(n):
	p = n
	while True:
		if number.isPrime(p := p+1): return p

n = ...
c = ...
root, is_exact = integer_nthroot(n, 3)
print(f"Căn bậc ba của n là: {root}")
while number.isPrime(root) == False:
	root -= 1
p = root
q = nextprime(p)
r = nextprime(q)
e = 0x10001
phi = (p-1) * (q-1) * (r-1)
d = pow(e, -1, phi)
print(long_to_bytes(pow(c, d, n)))
# Out:
# Căn bậc ba của n là: 8416495127953621175726923177729117769566943952776700764687291076539578723925933082933266154994811580158829377586999512607613060223691416027097795803122101
# b'ENO{1_l0ve_7h3_pr1me_numb3r_the0r3m}\n'
