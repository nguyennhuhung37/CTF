# %%
c = 
n = 
e = 65537

# %%
from math import prod

# Danh sách các số
numbers = [
    8932725433, 9078878857, 9146062291, 9268019297, 9513772591, 10204370963, 
    10373096621, 10568380091, 11907796333, 11994154307, 12269958433, 
    12511374257, 12548468479, 12691559809, 12944601179, 13262300951, 
    13278743747, 13828957187, 14059824043, 14125049153, 14340511511, 
    14588454631, 14930673833, 15345620551, 15363411379, 15472203599, 
    15619904611, 15697205141, 15757258241, 15801062909, 16278270133, 
    16542194831, 16637852939, 17148914743
]

# Tính tích (x - 1) với mọi x trong danh sách
phi = prod(x - 1 for x in numbers)
d = pow(e, -1, phi)
p = pow(c, d, n)
plaintext_ascii = bytes.fromhex(hex(p)[2:]).decode('utf-8')
print(plaintext_ascii)
# Out:
# picoCTF{too_many_fact0rs_0731311}
